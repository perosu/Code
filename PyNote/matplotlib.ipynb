# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.01, 5, 0.001)
y = []
for i in range(len(x)):
    y.append(math.sin(1 / x[i]))
# y = np.sum(x)
# x = np.arange(0,5,0.1)
# y = np.sin(x)
plt.plot(x,y)

# %%
import turtle
turtle.fd(100)
